# %%
# %load_ext autoreload
# %autoreload 2
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import sys
sys.path.append("/Users/ethanweber/Documents/cARd/server")
from vision_util import *

# %%
image_folder = "/Users/ethanweber/Documents/cARd/server/images"
image_filename = os.path.join(image_folder, "card_0.png")
image = cv2.imread(image_filename)
processed_image = get_cropped_and_rectified_image(image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))

# %%
search_string = get_search_string(processed_image)
print(type(search_string))
print(search_string)
# Out:
# <type 'str'>
# <type 'str'>
# https://www.google.com/search?q=Etsy%20Ryan%20Young%20Software%20Developer%20ryoung@etsy.com%20linkedin
