# %%
# %load_ext autoreload
# %autoreload 2
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import sys
sys.path.append("/Users/ethanweber/Documents/cARd/server")
from vision_util import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
image_folder = "/Users/ethanweber/Documents/cARd/server/images"
image_filename = os.path.join(image_folder, "card_3.png")
image = cv2.imread(image_filename)
processed_image = get_cropped_and_rectified_image(image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))

# %%
search_string = get_search_string(processed_image)
print(search_string)
# Out:
# https://www.google.com/search?q=linkedin%20RICHARD%20NI%20TECHNICAL%20PROJECT%20MANAGER%20richard@getcruise.com
