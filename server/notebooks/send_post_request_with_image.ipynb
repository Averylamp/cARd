# %%
# %load_ext autoreload
# %autoreload 2
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import sys
sys.path.append("/Users/ethanweber/Documents/cARd/server")
from vision_util import *
from app import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
text_file_path = "/Users/ethanweber/Documents/cARd/server/images/img64.txt"

headers = {
    'Content-Type': "application/json",
    'Cache-Control': "no-cache",
}

with open(text_file_path, 'r') as myfile:
    image_as_string=myfile.read().replace('\n', '')

# image_as_string

print(type(image_as_string))
import requests
import json

print(image_as_string)

data={'image_data': image_as_string}

r = requests.post("http://0.0.0.0:5000/handle_image", data=json.dumps(data), headers=headers)
# Out:
# <type 'str'>
# ...

# %%
print(r.text)
# Out:
# {
#   "cropped_image": "...",
#   "information": {
#     "currentEducation": "Saint Anselm College",
#     "description": "Campus Recruiter at Toast, Inc.",
#     "education_list": [
#       {
#         "begin_date": null,
#         "degree_name": "Bachelor of Arts",
#         "end_date": null,
#         "field_of_study": "English, Communications",
#         "school_name": "Saint Anselm College"
#       }
#     ],
#     "email": "CAsadorian@toasttab.com",
#     "links": {
#       "linkedin": [
#         "https://www.linkedin.com/in/christina-asadorian-034a4b34",
#         "https://www.linkedin.com/in/wreardon",
#         "https://www.linkedin.com/in/emily-mankowski-65b18443",
#         "https://www.linkedin.com/in/sarah-castle-cdr-01397a54"
#       ]
#     },
#     "name": "Christina Asadorian",
#     "phone_number": "9782396683",
#     "position_str": "Previously worked at Toast, Inc., Multiple Positions, Multiple Positions, .",
#     "positions_list": [
#       {
# ...
